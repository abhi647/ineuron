# %%
s = "this is My First Python programming class and i am learNING python string and its function"

# %%
#Questions

"""
1. Try to extract data from index one to index 300 with a jump of 3 
2. Try to reverse a string without using reverse function 
3. Try to split a string after conversion of entire string in uppercase 
4. try to convert the whole string into lower case 
5 . Try to capitalize the whole string 
6 . Write a diference between isalnum() and isalpha()
7. Try to give an example of expand tab
8 . Give an example of strip , lstrip and rstrip 
9.  Replace a string charecter by another charector by taking your own example 
10 . Try  to give a defination of string center function with and exmple 
11 . Write your own definition of compiler and interpretor without copy paste form internet in your own language
12 . Python is a interpreted of compiled language give a clear ans with your understanding 
13 . Try to write a usecase of python with your understanding """

# %%
#Q1. Try to extract data from index one to index 300 with a jump of 3 

s1 = s[1:300:3]
s1
# Out:
# 'h   r tnrrmglsnimeNGyosi dtfco'

# %%
#Q2. Try to reverse a string without using reverse function 

s2 = s[::-1]
s2
# Out:
# 'noitcnuf sti dna gnirts nohtyp GNINrael ma i dna ssalc gnimmargorp nohtyP tsriF yM si siht'

# %%
#Q3. Try to split a string after conversion of entire string in uppercase 

s3 = s.upper()
s4 =s3.split()
s4
# Out:
# ['THIS',
#  'IS',
#  'MY',
#  'FIRST',
#  'PYTHON',
#  'PROGRAMMING',
#  'CLASS',
#  'AND',
#  'I',
#  'AM',
#  'LEARNING',
#  'PYTHON',
#  'STRING',
#  'AND',
#  'ITS',
#  'FUNCTION']

# %%
#Q4. try to convert the whole string into lower case 
s5 = s.lower()
s5
# Out:
# 'this is my first python programming class and i am learning python string and its function'

# %%
#Q5 . Try to capitalize the whole string 

s6 = s.capitalize()
s6
# Out:
# 'This is my first python programming class and i am learning python string and its function'

# %%
#Q6 . Write a diference between isalnum() and isalpha()

#Ans:
"""isalnum() is used to check if the characters of the string is either number or alphabet 
isalpha() is used to check if the characters of the sting consist only alphabets"""
# Out:
# 'isalnum() is used to check if the characters of the string is either number or alphabet \nisalpha() is used to check if the characters of the sting consist only alphabets'

# %%
#Q7. Try to give an example of expand tab

s7 = s.expandtabs(tabsize=20)
s7
# Out:
# 'this is My First Python programming class and i am learNING python string and its function'

# %%
#8.Give an example of strip , lstrip and rstrip 

#Example for strip
s8 = "   Abhijit Singh   "
s9 = s8.strip()
s9
# Out:
# 'Abhijit Singh'

# %%
#Example for lstrip
s10 = "   Abhijit Singh"
s11 = s10.lstrip()
s11
# Out:
# 'Abhijit Singh'

# %%
#Example of rstrip
s12 = "Abhijit Singh   "
s13 = s12.rstrip()
s13
# Out:
# 'Abhijit Singh'

# %%
#Q9.Replace a string charecter by another charector by taking your own example 

s14 = s.replace("Python","Java")
s14
# Out:
# 'this is My First Java programming class and i am learNING python string and its function'

# %%
#Q10 . Try  to give a defination of string center function with and exmple 
"""Definition: String center is used to add spaces on left and right hand side of the string with a 
variable number of characters which can be mentioned in the fuction"""
s15 = s9.center(20)
s15
# Out:
# '   Abhijit Singh    '

# %% [markdown]
# ## Q11 . Write your own definition of compiler and interpretor without copy paste form internet in your own language
#
#
# ### Complier
# Complier converts a human understandable language to machine understandable language i.e. binary or 0,1
#
# ### Interpreter
#
# Interpreter directly executes the code without converting it first into machine understanable language

# %% [markdown]
# ## Q12 . Python is a interpreted of compiled language give a clear ans with your understanding

# %% [markdown]
# ## Q13 . Try to write a usecase of python with your understanding
#
# #### Ans: Python is the best language to work with data science as a widely popular language it have lot of contributors and there is the largest repositoty of libraries related to data science and machine learning and ease to use and clear sytax makes it even more usable
